# %% [markdown]
# <a href="https://colab.research.google.com/github/ffreirea1988/usm/blob/main/EDA%20Afectaci%C3%B3n%20FIF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Carga de datos
df_ACX = pd.read_excel('/content/Consolidado 2022 Banking (CL-PE-CO).xlsx'
                       #Si deseas que el ID de la tabla sea un campo dado de la tabla. En este caso: Clave de incidencia
                       #,index_col='Clave de incidencia'
                       )

# %%
#(Filas, Columnas)
df_ACX.shape
# Out:
# (1137, 12)

# %%
#Columnas
df_ACX.columns
# Out:
# Index(['Año', 'MES', 'Pais', 'Dia', 'Clave de incidencia', 'Nmb_Exp_Corp',
#        'Institución responsable', 'Tipificación', 'Vertical Responsable',
#        'Affected Services', 'Resumen', 'Afectación'],
#       dtype='object')

# %%
#Columnas y formato
df_ACX.dtypes
# Out:
# Año                        float64
# MES                         object
# Pais                        object
# Dia                          int64
# Clave de incidencia         object
# Nmb_Exp_Corp                object
# Institución responsable     object
# Tipificación                object
# Vertical Responsable        object
# Affected Services           object
# Resumen                     object
# Afectación                   int64
# dtype: object

# %%
df_ACX.head()
df_ACX.tail()
# Out:
#                      Año  MES   Pais  Dia Nmb_Exp_Corp  \
# Clave de incidencia
# GDEIP-1592           NaN  NaN  CMRMX   20          NaN
# GDEIP-1970           NaN  NaN  CMRMX   25          NaN
# GDEIP-2961           NaN  NaN  CMRMX   27          NaN
# GDEIP-2962           NaN  NaN  CMRMX   27          NaN
# GDEIP-2306           NaN  NaN  CMRMX   15          NaN
#
#                     Institución responsable            Tipificación  \
# Clave de incidencia
# GDEIP-1592                              FTC  Redes y Comunicaciones
# GDEIP-1970                          NEGOCIO       Paso a Producción
# GDEIP-2961                              FIF      Falla del Software
# GDEIP-2962                              FTC  Redes y Comunicaciones
# GDEIP-2306                          NEGOCIO            Error humano
#
#                     Vertical Responsable  \
# Clave de incidencia
# GDEIP-1592                           FTC
# GDEIP-1970                         CMRMX
# GDEIP-2961                         Cores
# GDEIP-2962                           FTC
# GDEIP-2306                         CMRMX
#
#                                                      Affected Services  \
# Clave de incidencia
# GDEIP-1592                                                  Datacenter
# GDEIP-1970                                                     Paytrue
# GDEIP-2961                                                     Paytrue
# GDEIP-2962           APP Mobile Parlo SAP SAT (Core Tarjetas) Weblo...
# GDEIP-2306                                                      PagoQR
#
#                                                                Resumen  \
# Clave de incidencia
# GDEIP-1592                         [CORP] Caída en múltiples servicios
# GDEIP-1970           [CMRMX] Falla en la activación de tarjetas des...
# GDEIP-2961           [BFCORP] Paytrue error en recibir trx NRT para...
# GDEIP-2962           [CROSS]Caida servicios SAT Mexico y CMR Puntos...
# GDEIP-2306           [CMRMX] Compras TC QR – Android no llega hacia...
#
#                      Afectación
# Clave de incidencia
# GDEIP-1592                    0
# GDEIP-1970                   31
# GDEIP-2961                    0
# GDEIP-2962                    0
# GDEIP-2306                   50

# %%
#Muestra análisis estadístico de variables numéricas
df_ACX.describe()
# Out:
#                Año          Dia    Afectación
# count  1111.000000  1137.000000  1.137000e+03
# mean   2022.627363    16.108179  1.257854e+04
# std       0.483724     8.699082  1.800972e+05
# min    2022.000000     1.000000  0.000000e+00
# 25%    2022.000000     8.000000  5.100000e+01
# 50%    2023.000000    17.000000  4.640000e+02
# 75%    2023.000000    23.000000  2.699000e+03
# max    2023.000000    31.000000  5.959750e+06

# %%
#Eliminar filas NA
df_ACX_sinNA = df_ACX.dropna()
#Reemplazar valores NA
#Forma básica: reemplazar nulos por ceros: df_ACX_ReemplazoNA = df_ACX.fillna(0)
df_ACX_ReemplazoNA = df_ACX.fillna({'Año':2023, 'MES': 0})
print(df_ACX_sinNA.shape)
print(df_ACX.shape)
print(df_ACX_ReemplazoNA.shape)
# Out:
# (1081, 12)
# (1137, 12)
# (1137, 12)

# %%
#Filtrar por columnas
df_clientes = df_ACX_ReemplazoNA[['Año', 'MES', 'Pais', 'Dia', 'Clave de incidencia', 'Nmb_Exp_Corp',
       'Institución responsable', 'Tipificación', 'Vertical Responsable',
       'Affected Services', 'Resumen', 'Afectación']]

# %%
#Filtrar por filas
#Filtrar por número de la fila
df_clientes.iloc[0:10]
df_clientes.iloc[0]
df_clientes.iloc[[0, 1, 2]]

#Filtrar por el valor del ID seleccionado (Clave de incidencia)
df_clientes.loc[[0,1],['Clave de incidencia','Afectación']]

#Filtrar por condiciones:
df_clientes[df_clientes['Afectación']>100]
df_clientes[(df_clientes['Afectación']>100) & (df_clientes['Nmb_Exp_Corp']=="Transferencias") & df_clientes['Resumen'].str.contains("BFCL")]
# Out:
#          Año    MES  Pais  Dia Clave de incidencia    Nmb_Exp_Corp  \
# 0     2022.0  junio  BFCL   14          GDEIP-1574  Transferencias
# 8     2022.0  julio  BFCL   13          GDEIP-1644  Transferencias
# 9     2022.0  julio  BFCL    6          GDEIP-1628  Transferencias
# 11    2022.0  julio  BFCL   19          GDEIP-1666  Transferencias
# 12    2022.0  julio  BFCL   25          GDEIP-1683  Transferencias
# ...      ...    ...   ...  ...                 ...             ...
# 1027  2023.0  junio  BFCL   30          GDEIP-3487  Transferencias
# 1029  2023.0  junio  BFCL   30          GDEIP-3512  Transferencias
# 1077  2023.0  julio  BFCL   13          GDEIP-3573  Transferencias
# 1081  2023.0  julio  BFCL    6          GDEIP-3528  Transferencias
# 1086  2023.0  julio  BFCL    7          GDEIP-3539  Transferencias
#
#      Institución responsable            Tipificación Vertical Responsable  \
# 0                        NaN  Redes y Comunicaciones                  FTC
# 8                        NaN           Base de Datos                  FTC
# 9                        FIF           Base de Datos                Cores
# 11                       NaN       Paso a Producción                Cores
# 12                   NEGOCIO       Error de Terceros   BFCL Integraciones
# ...                      ...                     ...                  ...
# 1027                     FTC         Infraestructura                  FTC
# 1029                     FIF      Falla del Software        Integraciones
# 1077                     FTC           Base de Datos                  NaN
# 1081                     FIF      Falla del Software        Integraciones
# 1086                     FIF      Falla del Software                  NaN
#
#           Affected Services  \
# 0            Transferencias
# 8            Transferencias
# 9            Transferencias
# 11               APP Mobile
# 12           Transferencias
# ...                     ...
# 1027           Pagos Tuxedo
# 1029  APP Mobile WebDesktop
# 1077         Transferencias
# 1081                 Canjes
# 1086  Avances/Super Avances
#
#                                                 Resumen  Afectación
# 0            [BFCL] - Caída 356 ATM's + Otros servicios       10324
# 8     [BFCL] - Errores en Servicio TercerosTransfere...       18029
# 9                   [BFCL] - Revision TEF por Problemas        1746
# 11                             [BFCL] Errores en la App       16848
# 12                              [BFCL] Problemas en TEF        5000
# ...                                                 ...         ...
# 1027       [BFCL] tiempos altos en multiples servicios.        9177
# 1029  [BFCL] Alerta con Transferencias Env, generan ...        5971
# 1077    [BFCL] Problemas con servicio de Transferencias       26444
# 1081        [BFCL] Altos tiempos en múltiples servicios       36877
# 1086                        [BFCL] Tiempos Altos en AZ7       21406
#
# [99 rows x 12 columns]

# %%
#Definir funciones de transformación
def TRX
