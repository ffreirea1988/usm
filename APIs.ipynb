# %% [markdown]
# <a href="https://colab.research.google.com/github/ffreirea1988/usm/blob/main/APIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import requests
import pandas as pd

# %%
class Mindicador:
    def __init__(self, indicador, year):
        self.indicador = indicador
        self.year = year

    def InfoApi(self):
        # Hacemos la solicitud para el caso de consulta de un indicador en un año determinado
        url = f'https://www.mindicador.cl/api/{self.indicador}/{self.year}'
        try:
            response = requests.get(url)
            response.raise_for_status()  # Lanza un error si la solicitud falla
            data = response.json()  # Usamos response.json() directamente

            # Verificar la estructura de los datos
            if isinstance(data, dict):
                if 'serie' in data:
                    # Si los datos están bajo la clave 'serie', extraer esa lista
                    data_list = data['serie']
                    df = pd.DataFrame(data_list)
                else:
                    print("La clave esperada 'serie' no está en la respuesta.")
                    df = pd.DataFrame()
            else:
                print("La respuesta no es un diccionario.")
                df = pd.DataFrame()

            return df

        except requests.exceptions.RequestException as e:
            return f"Error en la solicitud: {e}"

# %%
# Ejemplo de uso
indicador = Mindicador('uf', 2024)
df = indicador.InfoApi()

# %%
df.head()
# Out:
#                       fecha     valor
# 0  2024-09-09T03:00:00.000Z  37831.01
# 1  2024-09-08T04:00:00.000Z  37822.49
# 2  2024-09-07T04:00:00.000Z  37813.98
# 3  2024-09-06T04:00:00.000Z  37805.48
# 4  2024-09-05T04:00:00.000Z  37796.97
